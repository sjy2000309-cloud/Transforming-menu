# %%
import requests
import re
import json
from typing import List, Dict, Optional

# 你可以继续加页面，但建议先以“能稳定抽出高质量问答”为主
PAGE_TITLES = [
    "Japanese cuisine",
    "Chinese cuisine",
    "Korean cuisine",
    "Sushi",
    "Kimchi",
    "Ramen",
    "Soy sauce",
    "Tofu",
    "Tempura",
    "Udon",
    "Soba",
    "Peking duck",
    "Hot pot",
    "Dim sum",
    "Bibimbap",
    "Bulgogi",
    "Tteokbokki",
    "Rice",
    "Noodle",
    "Miso",
    "Seaweed",
    "Fish sauce",
    "Ginger",
    "Garlic",
    "Stir frying",
    "Steaming",
    "Deep frying",
    "Fermentation",
    "Braising",
    "Japanese tea ceremony",
    "Korean barbecue",
    "Street food"
]

# 用更“受控”的方式生成 benchmark：
# 1) 只对证据足够稳定的页面出题
# 2) 每个页面只生成少量高质量问题
# 3) 允许 paraphrase，但避免垃圾题和 etymology/历史噪声
QUESTION_SPECS = [
    {
        "title": "Soy sauce",
        "qa_type": "used_for",
        "templates": [
            "What is soy sauce used for?",
            "How is soy sauce commonly used?"
        ],
        "required_keywords": ["used", "dipping sauce", "seasoning"],
        "forbidden_keywords": ["breakfast", "style"],
        "search_limit": 80
    },
    {
        "title": "Miso",
        "qa_type": "used_for",
        "templates": [
            "What is miso used for?",
            "How is miso commonly used?"
        ],
        "required_keywords": ["used", "sauces", "pickling"],
        "forbidden_keywords": ["history", "vitamin", "breakfast"],
        "search_limit": 120
    },
    {
        "title": "Garlic",
        "qa_type": "used_for",
        "templates": [
            "What is garlic used for?",
            "How is garlic commonly used?"
        ],
        "required_keywords": ["used", "seasoning"],
        "forbidden_keywords": ["harvest", "cultivars"],
        "search_limit": 100
    },
    {
        "title": "Ginger",
        "qa_type": "used_for",
        "templates": [
            "What is ginger used for?",
            "How is ginger commonly used in cooking?"
        ],
        "required_keywords": ["used", "spice"],
        "forbidden_keywords": ["etymology", "summer of 1495"],
        "search_limit": 120
    },
    {
        "title": "Tempura",
        "qa_type": "origin",
        "templates": [
            "Where does tempura come from?",
            "Where did tempura originate?"
        ],
        "required_keywords": ["originated", "Portuguese"],
        "forbidden_keywords": ["témporas", "etymology"],
        "search_limit": 40
    },
    {
        "title": "Tofu",
        "qa_type": "origin",
        "templates": [
            "Where does tofu come from?"
        ],
        "required_keywords": ["originated", "China"],
        "forbidden_keywords": ["English word", "Japan during the Nara period"],
        "search_limit": 40
    },
    {
        "title": "Ramen",
        "qa_type": "origin",
        "templates": [
            "Where does ramen come from?"
        ],
        "required_keywords": ["origins", "Yokohama Chinatown"],
        "forbidden_keywords": ["Taiwan ramen", "Nagoya", "summer dish"],
        "search_limit": 80
    },
    {
        "title": "Ginger",
        "qa_type": "origin",
        "templates": [
            "Where does ginger come from?"
        ],
        "required_keywords": ["originated", "Maritime Southeast Asia"],
        "forbidden_keywords": ["etymology"],
        "search_limit": 60
    },
    {
        "title": "Bulgogi",
        "qa_type": "origin",
        "templates": [
            "Where does bulgogi come from?"
        ],
        "required_keywords": ["originated", "Goguryeo"],
        "forbidden_keywords": ["popular in Seoul"],
        "search_limit": 80
    },
    {
        "title": "Udon",
        "qa_type": "when",
        "templates": [
            "When is udon usually eaten or served?",
            "At what time of year is udon commonly eaten?"
        ],
        "required_keywords": ["summer", "winter"],
        "forbidden_keywords": ["Ise udon"],
        "search_limit": 80
    },
    {
        "title": "Dim sum",
        "qa_type": "when",
        "templates": [
            "When is dim sum usually eaten or served?",
            "At what meal is dim sum commonly eaten?"
        ],
        "required_keywords": ["breakfast", "brunch"],
        "forbidden_keywords": ["late-night snacks"],
        "search_limit": 120
    },
    {
        "title": "Kimchi",
        "qa_type": "when",
        "templates": [
            "When is kimchi usually eaten?"
        ],
        "required_keywords": ["side dish", "every Korean meal"],
        "forbidden_keywords": ["winter kimchi", "summer side dish"],
        "search_limit": 80
    },
    {
        "title": "Miso",
        "qa_type": "when",
        "templates": [
            "When is miso commonly eaten?"
        ],
        "required_keywords": ["breakfast"],
        "forbidden_keywords": ["history", "Kamakura period"],
        "search_limit": 140
    },
    {
        "title": "Peking duck",
        "qa_type": "served",
        "templates": [
            "How is peking duck usually served?",
            "How is peking duck traditionally served?"
        ],
        "required_keywords": ["served", "three stages"],
        "forbidden_keywords": ["served peking duck for lunch"],
        "search_limit": 120
    },
    {
        "title": "Hot pot",
        "qa_type": "served",
        "templates": [
            "How is hot pot usually served?",
            "How is hot pot traditionally served?"
        ],
        "required_keywords": ["served", "large metal pot"],
        "forbidden_keywords": ["Thai hot pot", "winter season"],
        "search_limit": 120
    },
    {
        "title": "Sushi",
        "qa_type": "served",
        "templates": [
            "How is sushi usually served?"
        ],
        "required_keywords": ["served", "pickled ginger"],
        "forbidden_keywords": ["term comes from", "three meals a day"],
        "search_limit": 120
    },
    {
        "title": "Soba",
        "qa_type": "served",
        "templates": [
            "How is soba usually served?"
        ],
        "required_keywords": ["served", "dipping sauce"],
        "forbidden_keywords": ["workers repairing", "Chinese origin"],
        "search_limit": 120
    },
    {
        "title": "Bulgogi",
        "qa_type": "served",
        "templates": [
            "How is bulgogi usually served?"
        ],
        "required_keywords": ["served", "rice"],
        "forbidden_keywords": ["barbecue restaurants"],
        "search_limit": 120
    },
    {
        "title": "Bibimbap",
        "qa_type": "served",
        "templates": [
            "How is bibimbap usually served?"
        ],
        "required_keywords": ["served", "warm white rice"],
        "forbidden_keywords": ["king", "between-meal snack"],
        "search_limit": 120
    },
    {
        "title": "Fish sauce",
        "qa_type": "used_for",
        "templates": [
            "What is fish sauce used for?"
        ],
        "required_keywords": ["used", "seasoning"],
        "forbidden_keywords": ["Thai meal is served"],
        "search_limit": 120
    },
    {
        "title": "Seaweed",
        "qa_type": "used_for",
        "templates": [
            "What is seaweed used for?"
        ],
        "required_keywords": ["used", "soups", "sushi"],
        "forbidden_keywords": ["introduced seaweed species"],
        "search_limit": 100
    }
]

# %%
def fetch_wikipedia_page(title: str):
    url = "https://en.wikipedia.org/w/api.php"
    params = {
        "action": "query",
        "prop": "extracts",
        "explaintext": 1,
        "titles": title,
        "format": "json",
        "redirects": 1
    }

    headers = {
        "User-Agent": "UoM-TRIM-coursework-benchmark/1.0 (student project)"
    }

    r = requests.get(url, params=params, headers=headers, timeout=20)
    r.raise_for_status()
    data = r.json()

    pages = data["query"]["pages"]
    page = next(iter(pages.values()))

    return {
        "title": title,
        "text": page.get("extract", "")
    }

# %%
def clean_text(text: str) -> str:
    text = text.replace("\n", " ").strip()
    text = re.sub(r"\s+", " ", text)
    return text

def split_sentences(text: str) -> List[str]:
    text = clean_text(text)
    return [s.strip() for s in re.split(r'(?<=[.!?])\s+', text) if s.strip()]

def strip_title_pronunciation(sentence: str, title: str) -> str:
    s = clean_text(sentence)

    title_re = re.escape(title)

    # 例如：
    # "Sushi (すし, 寿司) is ..."
    # -> "Sushi is ..."
    s = re.sub(
        rf"^{title_re}\s*\([^)]{{0,220}}\)\s*(?:is|are|was|were)\s*",
        f"{title} is ",
        s,
        flags=re.IGNORECASE
    )
    s = re.sub(
        rf"^{title_re}\s*\([^)]{{0,220}}\)\s*",
        f"{title} ",
        s,
        flags=re.IGNORECASE
    )

    return s.strip()

def normalize_leading_pronoun(answer: str, title: str) -> str:
    """
    把:
    - It is often served with ...
    - It originated in China ...
    改成:
    - Sushi is often served with ...
    - Tofu originated in China ...
    """
    s = clean_text(answer)

    # It is / It was / It originated ...
    s = re.sub(
        r"^It\s+(is|was|are|were)\b",
        f"{title} is",
        s,
        flags=re.IGNORECASE
    )
    s = re.sub(
        r"^It\s+originated\b",
        f"{title} originated",
        s,
        flags=re.IGNORECASE
    )
    s = re.sub(
        r"^It\s+comes\b",
        f"{title} comes",
        s,
        flags=re.IGNORECASE
    )
    s = re.sub(
        r"^It\s+is\s+often\b",
        f"{title} is often",
        s,
        flags=re.IGNORECASE
    )
    s = re.sub(
        r"^It\s+is\s+traditionally\b",
        f"{title} is traditionally",
        s,
        flags=re.IGNORECASE
    )
    s = re.sub(
        r"^It\s+is\s+served\b",
        f"{title} is served",
        s,
        flags=re.IGNORECASE
    )

    return s.strip()

def remove_non_culinary_tail(answer: str, title: str) -> str:
    """
    去掉不太适合 culinary QA benchmark 的尾巴
    例如:
    - garlic ... and traditional medical remedy
    - ginger ... and a folk medicine
    """
    s = clean_text(answer)

    if title.lower() == "garlic":
        s = re.sub(
            r",?\s*and\s+traditional medical remedy\b.*",
            "",
            s,
            flags=re.IGNORECASE
        )
        s = re.sub(
            r",?\s*as well as traditional medical remedy\b.*",
            "",
            s,
            flags=re.IGNORECASE
        )

    if title.lower() == "ginger":
        s = re.sub(
            r",?\s*and\s+a?\s*folk medicine\b.*",
            "",
            s,
            flags=re.IGNORECASE
        )
        s = re.sub(
            r",?\s*as well as a?\s*folk medicine\b.*",
            "",
            s,
            flags=re.IGNORECASE
        )

    s = re.sub(r"\s+,", ",", s)
    s = re.sub(r"\s+\.", ".", s)
    s = re.sub(r"\s{2,}", " ", s)

    return s.strip()

def clean_answer_text(answer: str, title: str) -> str:
    answer = clean_text(answer)

    # 去 heading
    answer = re.sub(r"^==+\s*[^=]+?\s*==+\s*", "", answer).strip()
    answer = re.sub(r"^=+\s*[^=]+?\s*=+\s*", "", answer).strip()
    answer = re.sub(r"==+\s*[^=]+?\s*==+", " ", answer).strip()

    # 去发音括号
    answer = strip_title_pronunciation(answer, title)

    # 把开头 It ... 改成显式主语
    answer = normalize_leading_pronoun(answer, title)

    # 去 culinary 任务里不需要的 medicine 尾巴
    answer = remove_non_culinary_tail(answer, title)

    # 收尾清洗
    answer = re.sub(r"\s+", " ", answer).strip()
    answer = re.sub(r"\s+([.,;:!?])", r"\1", answer)

    return answer.strip()

# %%
def build_sentence_windows(sentences: List[str]) -> List[str]:
    windows = []

    for i, s in enumerate(sentences):
        s = s.strip()
        if s:
            windows.append(s)

        # 当前句 + 下一句
        if i + 1 < len(sentences):
            pair = clean_text(s + " " + sentences[i + 1])
            if pair:
                windows.append(pair)

    # 去重但保持顺序
    deduped = []
    seen = set()
    for w in windows:
        key = w.lower()
        if key not in seen:
            deduped.append(w)
            seen.add(key)

    return deduped

def is_over_generic_item(title: str, spec: Dict) -> bool:
    """
    过滤太泛的实体，避免问题本身就不够干净。
    目前先只卡掉 seaweed 这种容易泛化失败的项。
    """
    generic_titles = {
        "seaweed",
    }
    return title.lower() in generic_titles

def score_candidate(candidate: str, spec: Dict, title: str) -> int:
    c = clean_answer_text(candidate, title)
    c_lower = c.lower()

    score = 0

    # 长度控制
    if len(c) < 20:
        score -= 5
    elif len(c) <= 180:
        score += 2
    elif len(c) <= 240:
        score += 0
    else:
        score -= 3

    # 句子数控制：尽量单句
    sentence_end_count = c.count(".") + c.count("?") + c.count("!")
    if sentence_end_count > 1:
        score -= 2

    # 主体相关性
    if title.lower() in c_lower:
        score += 2

    # required keywords: 每出现一个加分
    for kw in spec.get("required_keywords", []):
        if kw.lower() in c_lower:
            score += 3

    # forbidden keywords: 每出现一个重罚
    for kw in spec.get("forbidden_keywords", []):
        if kw.lower() in c_lower:
            score -= 7

    # 通用噪声
    noisy_patterns = [
        "etymology",
        "the term comes from",
        "may refer to",
        "pronounced",
        "this article",
        "romanized",
        "can refer to",
        "is a surname",
        "family name",
        "also known as",
    ]
    for bad in noisy_patterns:
        if bad in c_lower:
            score -= 6

    # 太泛的定义句，通常不适合直接当 answer
    weak_patterns = [
        "is a type of",
        "is a form of",
        "is a category of",
        "is a broad term",
    ]
    for bad in weak_patterns:
        if bad in c_lower:
            score -= 2

    qa_type = spec["qa_type"]

    if qa_type == "origin":
        if any(x in c_lower for x in [
            "originated",
            "origin",
            "introduced",
            "traced back",
            "comes from",
            "first appeared",
            "developed in",
        ]):
            score += 4

    elif qa_type == "used_for":
        if any(x in c_lower for x in [
            "used for",
            "used as",
            "seasoning",
            "ingredient",
            "condiment",
            "flavoring",
            "spice",
            "dipping sauce",
        ]):
            score += 4

    elif qa_type == "served":
        if any(x in c_lower for x in [
            "served",
            "traditionally served",
            "often served",
            "carved",
            "topped",
            "accompanied",
            "with sauce",
            "with broth",
        ]):
            score += 4

    elif qa_type == "when":
        if any(x in c_lower for x in [
            "breakfast",
            "brunch",
            "lunch",
            "dinner",
            "summer",
            "winter",
            "meal",
            "served hot",
            "served chilled",
            "eaten on",
        ]):
            score += 4

    # 开头是显式主语更好
    if c_lower.startswith(title.lower() + " "):
        score += 2

    # 代词开头扣分
    if re.match(r"^(it|they|this|these)\b", c_lower):
        score -= 3

    return score

def select_best_answer(title: str, text: str, spec: Dict) -> Optional[str]:
    if is_over_generic_item(title, spec):
        return None

    sentences = split_sentences(text)
    windows = build_sentence_windows(sentences)
    search_space = windows[: spec.get("search_limit", len(windows))]

    best_answer = None
    best_score = -10**9

    for cand in search_space:
        cleaned = clean_answer_text(cand, title)
        score = score_candidate(cleaned, spec, title)

        if score > best_score:
            best_score = score
            best_answer = cleaned

    # 最低门槛
    if best_answer is None or best_score < 7:
        return None

    return best_answer

# %%
def canonicalize_query(query: str) -> str:
    q = clean_text(query).lower().strip()
    q = re.sub(r"[^\w\s]", "", q)
    q = re.sub(r"\s+", " ", q)
    return q

def answer_signature(answer: str) -> str:
    """
    给答案做一个轻量签名，用来限制“同一答案被太多近义问题重复使用”
    """
    a = clean_text(answer).lower()
    a = re.sub(r"[^\w\s]", "", a)
    a = re.sub(r"\s+", " ", a)
    return a

def build_benchmark(question_specs: List[Dict]) -> List[Dict]:
    benchmark = []
    seen_queries = set()

    # 限制过多 paraphrase：同一个答案最多保留 2 个 query
    answer_to_count = {}

    # 缓存页面
    page_cache = {}

    def add_example(query: str, answer: str):
        if not answer:
            return

        q_key = canonicalize_query(query)
        if q_key in seen_queries:
            return

        a_key = answer_signature(answer)
        if answer_to_count.get(a_key, 0) >= 2:
            return

        benchmark.append({
            "query": query,
            "answer": answer
        })
        seen_queries.add(q_key)
        answer_to_count[a_key] = answer_to_count.get(a_key, 0) + 1

    for spec in question_specs:
        title = spec["title"]

        try:
            if title not in page_cache:
                page_cache[title] = fetch_wikipedia_page(title)
            doc = page_cache[title]
            text = doc["text"]
        except Exception as e:
            print(f"Skip {title}: {e}")
            continue

        if not text:
            continue

        answer = select_best_answer(title, text, spec)
        if not answer:
            print(f"Skip low-quality item: {title} / {spec['qa_type']}")
            continue

        for template in spec["templates"]:
            add_example(template, answer)

    return benchmark

# %%
benchmark = build_benchmark(QUESTION_SPECS)

print("Number of examples:", len(benchmark))
print(json.dumps(benchmark, indent=2, ensure_ascii=False))

with open("benchmark.json", "w", encoding="utf-8") as f:
    json.dump(benchmark, f, indent=2, ensure_ascii=False)

print("Saved benchmark.json")
# Out:
# Skip low-quality item: Miso / when
# Skip low-quality item: Seaweed / used_for
# Number of examples: 28
# [
#   {
#     "query": "What is soy sauce used for?",
#     "answer": "Soy sauce may be added directly to food and is commonly used as a dipping sauce or used as seasoning in cooking."
#   },
#   {
#     "query": "How is soy sauce commonly used?",
#     "answer": "Soy sauce may be added directly to food and is commonly used as a dipping sauce or used as seasoning in cooking."
#   },
#   {
#     "query": "What is miso used for?",
#     "answer": "Miso is used for sauces and spreads; pickling vegetables, fish, or meats; and mixing with dashi soup stock to serve as miso soup, a Japanese culinary staple food."
#   },
#   {
#     "query": "How is miso commonly used?",
#     "answer": "Miso is used for sauces and spreads; pickling vegetables, fish, or meats; and mixing with dashi soup stock to serve as miso soup, a Japanese culinary staple food."
#   },
#   {
# ...
